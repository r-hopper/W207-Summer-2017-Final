# %% [markdown]
# ## Shelter Animal Outcomes
# ### MIDS W207 Final Project
# ### Clay Miller, Roseanna Hopper, Yubo Zhang
# ### Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np

from sklearn.base import BaseEstimator, TransformerMixin
from bokeh.charts import Bar, output_file, show, output_notebook

# %matplotlib inline

# %%
from sklearn.cross_validation import train_test_split
import re

# Load the data
data = pd.read_csv('../data/train.csv')
data['OutcomeSubtype'] = data['OutcomeSubtype'].fillna('')
data['TotalOutcome'] = data['OutcomeType'].map(str) + "-" + data['OutcomeSubtype']
data['Female'] = 'Female' in data['SexuponOutcome']
del data['AnimalID']
data['Female'] = data['SexuponOutcome'].str.lower().str.contains('female')
data['Intact'] = data['SexuponOutcome'].str.lower().str.contains('intact')
data['MixBreed'] = data['Breed'].str.lower().str.contains('mix')
del data['SexuponOutcome']
data['AgeuponOutcome'].fillna('', inplace = True)

def ageConvert(age):
    regexyear = '(\d+) year'
    regexmnth = '(\d+) month'
    regexwk = '(\d+) week'
    regexday = '(\d+) day'
    if re.match(regexyear, age):
        const = int(re.match(regexyear, age).groups()[0])
        return const*52
    elif re.match(regexmnth, age):
        const = int(re.match(regexmnth, age).groups()[0])
        return const*4.5 # a month is roughly 4.5 weeks
    elif re.match(regexwk, age):
        return int(re.match(regexwk, age).groups()[0])
    elif re.match(regexday, age):
        const = int(re.match(regexday, age).groups()[0])
        return const/7 #7 days in a week
    else:
        return None
    
data['ConvertedAge']=data['AgeuponOutcome'].apply(ageConvert)


def mixed_breed(i):
    i = str(i)
    if i.find('Mix') >= 0: return 'Mixed Breed'
    if i.find('/') >= 0: return 'Known Breed Combo'
    return 'Nonmixed'
data['mixed_breed'] = data.Breed.apply(mixed_breed)


def naming(i):
    if pd.isnull(i): return 'Unnamed'
    return 'Named'
data['named'] = data.Name.apply(naming)

#Change all breed and color strings so that they are ordered consistently
#E.G. all "brown/black" and "black/brown" should become "black, brown"
def reorder(i):
    i = str(i)
    if i.find(" ") >= 0: i = i.replace(" ", "-")
    if i.find("/") >= 0: i = i.replace("/", " ")
    i = i.split()
    i = sorted(i)
    i = ' '.join(i)
    return i

data['OrderedColor'] = data.Color.apply(reorder)
data['OrderedBreed'] = data.Breed.apply(reorder)

# Set target and predictors
target = 'OutcomeType'
predictors = [c for c in data.columns if not c == target]

# Train/test split
X = data[predictors]
y = data[[target]]
X_train, X_dev, y_train, y_dev = train_test_split(X, y, random_state=2)

# %%
data.head()
# Out:
#       Name          DateTime      OutcomeType OutcomeSubtype AnimalType  \
# 0  Hambone   2/12/2014 18:22  Return_to_owner                       Dog
# 1    Emily  10/13/2013 12:44       Euthanasia      Suffering        Cat
# 2   Pearce   1/31/2015 12:28         Adoption         Foster        Dog
# 3      NaN   7/11/2014 19:09         Transfer        Partner        Cat
# 4      NaN  11/15/2013 12:52         Transfer        Partner        Dog
#
#   AgeuponOutcome                        Breed        Color  \
# 0         1 year        Shetland Sheepdog Mix  Brown/White
# 1         1 year       Domestic Shorthair Mix  Cream Tabby
# 2        2 years                 Pit Bull Mix   Blue/White
# 3        3 weeks       Domestic Shorthair Mix   Blue Cream
# 4        2 years  Lhasa Apso/Miniature Poodle          Tan
#
#            TotalOutcome Female Intact MixBreed  ConvertedAge  \
# 0      Return_to_owner-  False  False     True          52.0
# 1  Euthanasia-Suffering   True  False     True          52.0
# 2       Adoption-Foster  False  False     True         104.0
# 3      Transfer-Partner  False   True     True           3.0
# 4      Transfer-Partner  False  False    False         104.0
#
#          mixed_breed    named OrderedColor                 OrderedBreed
# 0        Mixed Breed    Named  Brown White        Shetland-Sheepdog-Mix
# 1        Mixed Breed    Named  Cream-Tabby       Domestic-Shorthair-Mix
# 2        Mixed Breed    Named   Blue White                 Pit-Bull-Mix
# 3        Mixed Breed  Unnamed   Blue-Cream       Domestic-Shorthair-Mix
# 4  Known Breed Combo  Unnamed          Tan  Lhasa-Apso Miniature-Poodle

# %%
#A quick look at the variables

#Animal types
animal_type = data['AnimalType'].value_counts() 
animal_type.plot(kind='bar',color='#34ABD8',rot=0)

# %%
#Animal types
output_notebook()
p = Bar(data, label='OutcomeType', values = 'AnimalType', agg='count', stack='AnimalType',
        title="Outcomes by Animal Type", legend='top_right')
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0da70883-7a99-4ddd-94ba-483ed77469ca">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="f163749e-4d34-4384-bd0b-f6d77485df55"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#f163749e-4d34-4384-bd0b-f6d77485df55").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f163749e-4d34-4384-bd0b-f6d77485df55");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f163749e-4d34-4384-bd0b-f6d77485df55' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"0c420bde-b517-4ef9-a26f-6dae2920b827":{"roots":{"references":[{"attributes":{"axis_label":"Count( Animaltype )","formatter":{"id":"5d2c6a91-a46a-4ef5-900d-fab98c707248","type":"BasicTickFormatter"},"plot":{"id":"d8207c23-31f1-41a1-bda8-3238b7583c34","subtype":"Chart","type":"Plot"},"ticker":{"id":"39ffa3f1-21dc-44af-ba0d-74101cb3137d","type":"BasicTicker"}},"id":"9d019807-6d92-41f6-bcdf-29a3ced75b0f","type":"LinearAxis"},{"attributes":{"data_source":{"id":"df627d59-311e-48ac-9131-ed8701001333","type":"ColumnDataSource"},"glyph":{"id":"6102b431-2032-4ceb-ad57-0f89f750f6b6","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3ddf4e6b-f450-44ea-b1f3-10345e51cd1e","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"da741c04-1be1-47cd-88e0-e5bc66a40932","type":"ColumnDataSource"},"glyph":{"id":"c2fc5286-6b8f-4e4d-b0e6-eed4312c63af","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"58f2f53c-c76e-4b41-b2da-70b9c3b9925d","type":"GlyphRenderer"},{"attributes":{"callback":null,"factors":["Adoption","Died","Euthanasia","Return_to_owner","Transfer"]},"id":"63cfd7fd-ae1c-4c4b-8311-2d374e213a68","type":"FactorRange"},{"attributes":{"plot":null,"text":"Outcomes by Animal Type"},"id":"25098917-a009-4c95-85c3-5bd5e1dddc52","type":"Title"},{"attributes":{"overlay":{"id":"cea88281-2b65-44af-a431-a92157b81649","type":"BoxAnnotation"},"plot":{"id":"d8207c23-31f1-41a1-bda8-3238b7583c34","subtype":"Chart","type":"Plot"}},"id":"30eef202-bf4d-448b-a2c6-682f1a78dc74","type":"BoxZoomTool"},{"attributes":{},"id":"8c849e3e-2377-4e91-b1b0-fa8154ca9aec","type":"CategoricalTickFormatter"},{"attributes":{"plot":{"id":"d8207c23-31f1-41a1-bda8-3238b7583c34","subtype":"Chart","type":"Plot"}},"id":"a646402b-600d-4004-91d3-e2f7b3f00898","type":"PanTool"},{"attributes":{"data_source":{"id":"be4285e1-1bb3-4d8c-945e-b6b6b90ff071","type":"ColumnDataSource"},"glyph":{"id":"3750d723-2563-4991-b114-9704e97b258f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"8a89c866-e776-4639-ae40-0dafd59e05df","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d1d3f63b-d909-451f-b7b1-cd1207a5727b","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6102b431-2032-4ceb-ad57-0f89f750f6b6","type":"Rect"},{"attributes":{"data_source":{"id":"34568c08-04ed-4114-afd9-9f9293993476","type":"ColumnDataSource"},"glyph":{"id":"0e7b50ac-84e6-4c92-8a6c-ea445b490464","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"33c284a2-f727-47b4-8731-b5cf3eedb98b","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8533b39e-d451-4daf-96eb-57cf818bb8d2","type":"Rect"},{"attributes":{"data_source":{"id":"17968eb2-4a3a-4f25-a7b1-8ec1bded7d82","type":"ColumnDataSource"},"glyph":{"id":"ea3e2e4f-0c04-4b28-8587-794262e2effc","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"293eafed-bf8c-4112-9e5c-a5b06f3989b4","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"d8207c23-31f1-41a1-bda8-3238b7583c34","subtype":"Chart","type":"Plot"}},"id":"686629a1-8e3f-4190-b12d-f27202454b26","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"AnimalType":["Dog"],"Out ...

# %%
#Outcome types
outcome_type = data['OutcomeType'].value_counts() 
outcome_type.plot(kind='bar',color='#34ABD8',rot=0)

# %%
#Spayed/neutered
intact_type = data['Intact'].value_counts() 
intact_type.plot(kind='bar',color='#34ABD8',rot=0)

# %%
p = Bar(data, label='OutcomeType', values = 'Intact', agg='count', stack='Intact',
        title="Outcomes by Intact Status", legend='top_right')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="fc6427c2-db5e-491f-8a79-1dce78928fe8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#fc6427c2-db5e-491f-8a79-1dce78928fe8").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fc6427c2-db5e-491f-8a79-1dce78928fe8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fc6427c2-db5e-491f-8a79-1dce78928fe8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5b646926-98f2-4e51-84fd-a88a7deb5a67":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"73766035-449e-4fbd-8a24-cfb7123b9010","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"73766035-449e-4fbd-8a24-cfb7123b9010","type":"BoxAnnotation"},"plot":{"id":"3222429c-9dec-45ce-916a-4524d0dde428","subtype":"Chart","type":"Plot"}},"id":"fcb72dfb-353e-41df-9737-5dafbd67905c","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"b7421542-5010-4f86-8fc8-4d3e56ccf3fb","type":"ColumnDataSource"},"glyph":{"id":"25ba25c1-4150-4d99-b1ab-9268724612e1","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3b57db19-97f2-4dbc-8d68-a03aa1095e8d","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"42fd0b7e-3b91-40b6-80ca-888924d064d9","type":"ColumnDataSource"},"glyph":{"id":"822d3397-ad48-4813-83ad-e8f689c53556","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"94edaa99-d503-4f9a-aa09-555f361f97fe","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Intact":[false],"OutcomeType":["Euthanasia"],"chart_index":[{"Intact":false,"OutcomeType":"Euthanasia"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[677.0],"label":[{"Intact":false,"OutcomeType":"Euthanasia"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Euthanasia"],"y":[338.5]}},"id":"fa9a9eae-1009-4c3a-be77-bd7716ba6e39","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"3222429c-9dec-45ce-916a-4524d0dde428","subtype":"Chart","type":"Plot"}},"id":"39ef0bb7-d3d4-480b-a880-b562eb89f79f","type":"HelpTool"},{"attributes":{"callback":null,"end":11307.45},"id":"d27c996b-f6b9-4f6e-b226-db1fe60c7e82","type":"Range1d"},{"attributes":{"axis_label":"Outcometype","formatter":{"id":"c728e76e-4120-4cd0-8f0e-b0b94a3302a1","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"3222429c-9dec-45ce-916a-4524d0dde428","subtype":"Chart","type":"Plot"},"ticker":{"id":"3e5f7606-b159-4297-8807-ac1a16ad54c7","type":"CategoricalTicker"}},"id":"6cb70345-eb99-441d-b798-38d562475577","type":"CategoricalAxis"},{"attributes":{"data_source":{"id":"2a94fce9-ab81-41ed-b542-33cd832fab1e","type":"ColumnDataSource"},"glyph":{"id":"2e486de6-b0c2-4108-a1a8-4f07c143f79c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"33262f6c-cda0-4cf7-ab13-367ed4dda7e2","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Intact":[false],"OutcomeType":["Died"],"chart_index":[{"Intact":false,"OutcomeType":"Died"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[62.0],"label":[{"Intact":false,"OutcomeType":"Died"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Died"],"y":[166.0]}},"id":"946bf89b-f7b7-4b04-9fae-e43ea81cafb8","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"46ef166e-f546-460c-941a-186863a59b92","type":"Rect"},{"attributes":{},"id":"bf302f7d-bab3-4835-b092-8a3f77b29913","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"79b19020-915c-4a35-ae94-8b47a44d9de ...

# %%
#Sex
intact_type = data['Female'].value_counts() 
intact_type.plot(kind='bar',color='#34ABD8',rot=0)

# %%
p = Bar(data, label='OutcomeType', values = 'Female', agg='count', stack='Female',
        title="Outcomes by Female", legend='top_right')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="f264ee96-d937-4a2a-a04e-f75f98e607cd"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#f264ee96-d937-4a2a-a04e-f75f98e607cd").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f264ee96-d937-4a2a-a04e-f75f98e607cd");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f264ee96-d937-4a2a-a04e-f75f98e607cd' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d183d3ad-73a5-4b5b-9955-c08e87f12c1b":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fbda9790-7abc-482c-b8a8-5b5e2b17c9ff","type":"Rect"},{"attributes":{"data_source":{"id":"b3f308d2-d805-40b1-ac8e-7d36774a93f6","type":"ColumnDataSource"},"glyph":{"id":"e23a6648-6fc5-4e73-aec9-f059c5183a15","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4b204f6a-24d0-4fd0-b732-40af00b3c469","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cd8316e1-72d6-4ecf-9827-1feb5da2531d","type":"Rect"},{"attributes":{"data_source":{"id":"8492cdad-5372-458a-bbdd-5ca771c79c9b","type":"ColumnDataSource"},"glyph":{"id":"1a9fcaea-ec2a-43aa-afdf-784a75e226ad","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d8697ace-42a8-4e39-9423-8e120353f676","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"c7b88059-0a75-4580-9039-5756ea1a8904","type":"ColumnDataSource"},"glyph":{"id":"d26a0b56-a8a3-4cfb-9dcd-fa7f7542352a","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"7714eb6e-346a-4a65-8294-28e34f6da45b","type":"GlyphRenderer"},{"attributes":{},"id":"a28bb784-8983-46fd-9941-f76cf50e8ca9","type":"ToolEvents"},{"attributes":{"data_source":{"id":"e6190fe2-32bf-465e-8dc5-ed84a20069d0","type":"ColumnDataSource"},"glyph":{"id":"cd8316e1-72d6-4ecf-9827-1feb5da2531d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"77d49a7a-af70-4b2a-a744-43ea6079c040","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1a9fcaea-ec2a-43aa-afdf-784a75e226ad","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Female":[true],"OutcomeType":["Adoption"],"chart_index":[{"Female":true,"OutcomeType":"Adoption"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[5389.0],"label":[{"Female":true,"OutcomeType":"Adoption"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Adoption"],"y":[8074.5]}},"id":"b0532e79-07a8-4d00-86ec-a08105a63b69","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"c8241e8b-361a-4bbd-b6e4-9116bd9ea536","type":"BoxAnnotation"},"plot":{"id":"aa7ed234-a13c-4cb4-875b-1f379283ef0f","subtype":"Chart","type":"Plot"}},"id":"609505ca-6b9d-4026-bc84-d2312fd908d2","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"aa7ed234-a13c-4cb4-875b-1f379283ef0f","subtype":"Chart","type":"Plot"}},"id":"bcbd2874-1d5a-4912-9306-002c5794a36e","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Female":[false],"OutcomeType":["Return_to_owner"],"chart_index":[{"Female":false,"OutcomeType":"Return_to_owner"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2736.0],"label":[{"Female":false,"OutcomeType":"Return_to_owner"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Return_to_owner"],"y":[1368.0]}},"id":"31f6af6a-4f92-47fb-8a31-c80285150180","type":"ColumnDataSource"},{"attributes":{"axis_label":"Count( Female )","formatter":{"id":"588383ad-be1d-4f95-8eca-0f38ee31cc3b","type":"BasicTickFormatter"},"plot":{"id":"aa7ed234-a13c-4cb4-875b-1f379283ef0f","subtype":"Chart","type":"Plot"},"ticker":{"id":"88c62b6b-3a9c-40ba-9683-4182 ...

# %%
#Purebred/mixed

mixed_breed = data['mixed_breed'].value_counts() 
mixed_breed.plot(kind='bar',color='#34ABD8',rot=0)

# %%
p = Bar(data, label='OutcomeType', values = 'mixed_breed', agg='count', stack='mixed_breed',
        title="Outcomes by Breed Type", legend='top_right')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="1b7cb7ca-8924-443d-a973-e8481b0b4209"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#1b7cb7ca-8924-443d-a973-e8481b0b4209").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1b7cb7ca-8924-443d-a973-e8481b0b4209");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1b7cb7ca-8924-443d-a973-e8481b0b4209' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"c55ae34a-54db-4ddf-946f-0d4b6fdb7997":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7abad3e3-2b53-4e4e-8541-68c9071dd176","type":"Rect"},{"attributes":{"legends":[["Mixed Breed",[{"id":"a22e788d-73f4-4211-9e60-5d8d7620a600","type":"GlyphRenderer"}]],["Known Breed Combo",[{"id":"8ae01911-9969-4d94-95cc-0f5339ef963b","type":"GlyphRenderer"}]],["Nonmixed",[{"id":"5a1b833f-ddee-4769-badb-501fb5e95d19","type":"GlyphRenderer"}]]],"plot":{"id":"2803380e-6f3d-4074-abf0-c021a3e69be7","subtype":"Chart","type":"Plot"}},"id":"c61d43f8-ad84-4226-8618-2ad972bcfe6a","type":"Legend"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"OutcomeType":["Transfer"],"chart_index":[{"OutcomeType":"Transfer","mixed_breed":"Mixed Breed"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[8252.0],"label":[{"OutcomeType":"Transfer","mixed_breed":"Mixed Breed"}],"line_alpha":[1.0],"line_color":["white"],"mixed_breed":["Mixed Breed"],"width":[0.8],"x":["Transfer"],"y":[4126.0]}},"id":"c1bb6fb9-6974-4942-83d2-f3010ff4e70e","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"8f1fcb5d-14e0-485b-9f3b-8fb1f0b10fe1","type":"ColumnDataSource"},"glyph":{"id":"3a6c48fc-81b3-4e3c-bcc6-3d511ece302c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"8e6a0ff8-e367-4743-b35a-c6b6b26505bb","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"2803380e-6f3d-4074-abf0-c021a3e69be7","subtype":"Chart","type":"Plot"}},"id":"db8a185e-f68b-4c2c-9be3-f61e67a70370","type":"PanTool"},{"attributes":{"data_source":{"id":"6fb3dac9-681e-4c30-99ea-1c54e06d8346","type":"ColumnDataSource"},"glyph":{"id":"d6c02655-7843-4467-89b5-8e711e9fb3fa","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b0363a1b-f2f7-415e-84af-e7d78ce53767","type":"GlyphRenderer"},{"attributes":{"axis_label":"Count( Mixed_Breed )","formatter":{"id":"33d47a0f-fd60-4f39-892e-86b54ff9c8e0","type":"BasicTickFormatter"},"plot":{"id":"2803380e-6f3d-4074-abf0-c021a3e69be7","subtype":"Chart","type":"Plot"},"ticker":{"id":"8f838437-f536-47cd-8abd-6f599161b5f0","type":"BasicTicker"}},"id":"98409aa6-86bb-4f1d-a9c3-2e9686255411","type":"LinearAxis"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"09d77698-ae9b-4f63-8640-503986fd8c77","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"OutcomeType":["Transfer"],"chart_index":[{"OutcomeType":"Transfer","mixed_breed":"Nonmixed"}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[436.0],"label":[{"OutcomeType":"Transfer","mixed_breed":"Nonmixed"}],"line_alpha":[1.0],"line_color":["white"],"mixed_breed":["Nonmixed"],"width":[0.8],"x":["Transfer"],"y":[9204.0]}},"id":"d65bd25e-2997-4d3b-bccb-a129c61a5b11","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":"Outcomes by Breed Type"},"id":"bd9ff3f4-e5f0-47f2-9900-a1ee986ff1ad","type":"Title"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"OutcomeType":["Adoption"],"chart_index":[{"OutcomeType":"Adoption","mixed_breed":"Nonmixed"}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[443.0],"label":[{"OutcomeType":"Adoption","mixed_breed":"Nonmixed"}],"line_alpha":[1.0],"line_color":["white"],"mixed_breed":["Nonmixed"],"width":[0.8],"x":["Adoption"],"y":[9013.5]}},"id":"8d8fbe1a-24e4-46c5-807e-6f0a83856734","type":"ColumnDataSource"}, ...

# %%
data.hist(column="ConvertedAge", bins=25)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000000109AF4E0>]], dtype=object)

# %%
p = Bar(data, label='OutcomeType', values = 'ConvertedAge', agg='mean',
        title="Outcomes by Age", legend='top_right')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="6d3f4863-c1a3-4e03-8410-4e02831537fd"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#6d3f4863-c1a3-4e03-8410-4e02831537fd").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6d3f4863-c1a3-4e03-8410-4e02831537fd");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6d3f4863-c1a3-4e03-8410-4e02831537fd' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"fe571b1c-dd60-4374-addd-17c9751adb48":{"roots":{"references":[{"attributes":{"data_source":{"id":"c45c47b0-57c5-4ee8-98f5-688ebcd683f0","type":"ColumnDataSource"},"glyph":{"id":"271ce698-82a2-4b8a-b368-2fef71a5157d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a21e9c1e-9639-45c2-85d5-8b4adba62361","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"0f9bb2ea-a8c5-4267-8fb2-59dcd17534a4","type":"ColumnDataSource"},"glyph":{"id":"63593496-cb57-4550-9391-8b71cc2c1020","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a58db578-41be-41bc-9382-4d0984988c4a","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"892d8960-ea24-4b10-9ede-de35366948d8","subtype":"Chart","type":"Plot"}},"id":"5ccb538f-021b-4d48-b2d1-ddacc1344598","type":"WheelZoomTool"},{"attributes":{"below":[{"id":"d94eb504-b925-4257-8061-c93e51afa353","type":"CategoricalAxis"}],"left":[{"id":"f50da6da-e4c4-4cc4-a50e-18f5d7ff45d2","type":"LinearAxis"}],"renderers":[{"id":"eb066d4d-8f42-4eb8-a914-23953193790e","type":"BoxAnnotation"},{"id":"a58db578-41be-41bc-9382-4d0984988c4a","type":"GlyphRenderer"},{"id":"de1a050c-d0db-4c11-8243-f2b5d20cfd09","type":"GlyphRenderer"},{"id":"32cca329-2780-4be4-8206-34a93194f10c","type":"GlyphRenderer"},{"id":"9622c3e8-7c15-4f89-866c-1dff2b74df75","type":"GlyphRenderer"},{"id":"a21e9c1e-9639-45c2-85d5-8b4adba62361","type":"GlyphRenderer"},{"id":"709c0417-c90e-4ec1-bafa-4b1951ea8a2a","type":"Legend"},{"id":"d94eb504-b925-4257-8061-c93e51afa353","type":"CategoricalAxis"},{"id":"f50da6da-e4c4-4cc4-a50e-18f5d7ff45d2","type":"LinearAxis"},{"id":"dd1184c0-54ec-449b-9743-97dcac365973","type":"Grid"}],"title":{"id":"ad4d0f6a-9020-4b0f-bd8b-1d6124fb93de","type":"Title"},"tool_events":{"id":"7649146d-2acb-47a6-99fb-e8db4976013c","type":"ToolEvents"},"toolbar":{"id":"5a1e902c-42e3-4949-85e6-da6e4641c950","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"0baf8a8d-c812-4dfd-b929-b03cecce5c63","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"857f5dc0-fc33-4e81-a1ad-ec2ff528bc7e","type":"Range1d"}},"id":"892d8960-ea24-4b10-9ede-de35366948d8","subtype":"Chart","type":"Plot"},{"attributes":{"axis_label":"Mean( Convertedage )","formatter":{"id":"0638c0ba-ab94-414d-a3d5-b3962b3852af","type":"BasicTickFormatter"},"plot":{"id":"892d8960-ea24-4b10-9ede-de35366948d8","subtype":"Chart","type":"Plot"},"ticker":{"id":"5974cfbc-e257-4076-849c-35df5edba1d3","type":"BasicTicker"}},"id":"f50da6da-e4c4-4cc4-a50e-18f5d7ff45d2","type":"LinearAxis"},{"attributes":{},"id":"0638c0ba-ab94-414d-a3d5-b3962b3852af","type":"BasicTickFormatter"},{"attributes":{"axis_label":"Outcometype","formatter":{"id":"c729395a-93b9-412f-a6bb-1de6abe1bf27","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"892d8960-ea24-4b10-9ede-de35366948d8","subtype":"Chart","type":"Plot"},"ticker":{"id":"81a469a8-895e-426e-899c-e653deb07810","type":"CategoricalTicker"}},"id":"d94eb504-b925-4257-8061-c93e51afa353","type":"CategoricalAxis"},{"attributes":{},"id":"81a469a8-895e-426e-899c-e653deb07810","type":"CategoricalTicker"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"31dc0f48-ed22-4cfb-ad57-4416c5a74d8e","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"271ce698-82a2-4b8a-b368-2fef71a5157d","type":"Rect"},{"attributes":{},"id":"5974cfbc-e257-4076-849c-35df5edba1d3","type":"BasicTicker"},{"attributes":{"plot":{"id":"892d8960-ea24-4b10-9ede-de35366948d8","subtype":"Chart","type":"Plot"}},"id":"44514f06-be39-4d83-91c5-9e4 ...

# %%
#Named/unnamed

name = data['named'].value_counts() 
name.plot(kind='bar',color='#34ABD8',rot=0)

# %%
p = Bar(data, label='OutcomeType', values = 'named', agg='count', stack='named',
        title="Outcomes by Name Status", legend='top_right')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="514aedd1-97f7-45ff-9640-36831e3ca943"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#514aedd1-97f7-45ff-9640-36831e3ca943").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("514aedd1-97f7-45ff-9640-36831e3ca943");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '514aedd1-97f7-45ff-9640-36831e3ca943' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"cdb3a16e-6c34-4372-84a2-39025d1fd583":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"368450e0-1f60-4c6f-a80a-84bb7c7aef56","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"OutcomeType":["Return_to_owner"],"chart_index":[{"OutcomeType":"Return_to_owner","named":"Unnamed"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[153.0],"label":[{"OutcomeType":"Return_to_owner","named":"Unnamed"}],"line_alpha":[1.0],"line_color":["white"],"named":["Unnamed"],"width":[0.8],"x":["Return_to_owner"],"y":[4709.5]}},"id":"23eaad14-5fb9-465e-bd79-b68d30db5e2c","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"OutcomeType":["Transfer"],"chart_index":[{"OutcomeType":"Transfer","named":"Named"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[4497.0],"label":[{"OutcomeType":"Transfer","named":"Named"}],"line_alpha":[1.0],"line_color":["white"],"named":["Named"],"width":[0.8],"x":["Transfer"],"y":[7173.5]}},"id":"3f13919a-d74c-4a24-91f2-cbda078b73ed","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":11307.45},"id":"0d6669d6-e1c3-402c-937f-72e7c2cce166","type":"Range1d"},{"attributes":{"data_source":{"id":"3f13919a-d74c-4a24-91f2-cbda078b73ed","type":"ColumnDataSource"},"glyph":{"id":"26bdd0a8-5cff-4ae8-a467-2af61a632a0e","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"841b1f90-71e7-4ae8-83d7-cc4d4a0214d4","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"OutcomeType":["Died"],"chart_index":[{"OutcomeType":"Died","named":"Unnamed"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[120.0],"label":[{"OutcomeType":"Died","named":"Unnamed"}],"line_alpha":[1.0],"line_color":["white"],"named":["Unnamed"],"width":[0.8],"x":["Died"],"y":[137.0]}},"id":"58dd061f-f3eb-4e0d-aea3-61fa3015852d","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f3162ecf-8744-4fb7-b37b-11fcd7d07602","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d493ebab-1bc8-4a48-ba07-ab8fe3a0ce33","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"39eb330d-b9f8-47bd-ae72-5ad2d90de74c","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"OutcomeType":["Euthanasia"],"chart_index":[{"OutcomeType":"Euthanasia","named":"Unnamed"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[815.0],"label":[{"OutcomeType":"Euthanasia","named":"Unnamed"}],"line_alpha":[1.0],"line_color":["white"],"named":["Unnamed"],"width":[0.8],"x":["Euthanasia"],"y":[1147.5]}},"id":"759ee710-7101-459d-a772-0c1663eaa543","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field ...

# %%
OrderedColor = data.OrderedColor.unique()
print("Unique Colors" , (data.OrderedColor.value_counts() > 0).sum())
print(OrderedColor)
# Out:
# ('Unique Colors', 275)
# ['Brown White' 'Cream-Tabby' 'Blue White' 'Blue-Cream' 'Tan' 'Black Tan'
#  'Blue-Tabby' 'Brown-Tabby' 'Red White' 'White' 'Black' 'Silver' 'Brown'
#  'Black Red' 'Cream White' 'Orange-Tabby White' 'Black White'
#  'Brown-Brindle White' 'Black Brown' 'Orange-Tabby' 'Chocolate White'
#  'Tan White' 'Cream-Tabby White' 'Blue' 'Calico' 'Torbie' 'Yellow'
#  'Tricolor' 'Tortie' 'Blue-Tabby White' 'Gray White' 'Buff'
#  'Brown-Tabby White' 'Red' 'Blue Tan' 'Seal-Point' 'Brown-Brindle' 'Gray'
#  'White Yellow-Brindle' 'Fawn White' 'Flame-Point' 'Black-Tabby White'
#  'Calico Tortie' 'Black Brown-Brindle' 'Silver Tan' 'Black Red-Tick'
#  'Blue-Merle' 'Chocolate Tan' 'Sable' 'Brown-Merle White'
#  'Brown-Tiger White' 'Liver White' 'Black Gray' 'Cream' 'Chocolate'
#  'Blue-Point' 'Apricot White' 'Black Red-Merle' 'Blue-Merle White' 'Fawn'
#  'Lynx-Point White' 'Black Fawn' 'Red-Tick White' 'Buff Tan'
#  'Brown-Brindle Red-Tick' 'Lilac-Point' 'Buff White' 'Tortie-Point'
#  'Lynx-Point' 'Tortie White' 'Black Tricolor' 'Apricot' 'Red Tan'
#  'Brown Tan' 'Tricolor White' 'Brown Tricolor' 'White White' 'Gray-Tabby'
#  'Sable White' 'Blue-Tiger White' 'Yellow-Brindle' 'Gold' 'Blue-Tick'
#  'Torbie White' 'Black-Smoke White' 'Blue-Tabby Orange' 'Red-Merle'
#  'Blue Tricolor' 'White Yellow' 'Black-Smoke' 'Calico-Point'
#  'Blue-Cream Blue-Tiger' 'Blue-Merle Gray' 'Brown Silver' 'Black Sable'
#  'Black-Brindle' 'Lynx-Point Tortie-Point' 'Black Buff' 'Calico White'
#  'Orange White' 'Black-Tabby' 'Brown-Merle' 'Black-Brindle White'
#  'Gray Tan' 'Blue-Merle Brown' 'Red-Merle White' 'Chocolate-Point White'
#  'Black Silver' 'Cream Red-Tick' 'Chocolate Gold' 'Calico-Point White'
#  'Brown Brown' 'Seal-Point White' 'Brown Sable' 'Brown-Tabby Calico'
#  'Silver-Tabby' 'Blue-Merle Tan' 'Black Blue-Tick' 'Black Cream'
#  'Chocolate Tricolor' 'Gold White' 'Cream Gray' 'Black Blue-Merle'
#  'Red Red-Tick' 'Orange' 'Black Orange' 'Blue-Cream Tortie'
#  'Brown Red-Tick' 'Blue Brown-Brindle' 'Black Silver-Tabby' 'Gray Silver'
#  'Gold Red' 'Gold Tan' 'Blue-Cream Blue-Tabby' 'Cream Tan' 'Black Calico'
#  'Sable Tan' 'Black Blue' 'Black Brown-Tabby' 'Cream Red' 'Brown-Tiger'
#  'Agouti' 'Calico Tricolor' 'Black Black' 'Blue-Cream White' 'Brown Gray'
#  'Blue-Point White' 'Gray-Tabby White' 'Red-Tick Tan'
#  'Apricot Orange-Tabby' 'Fawn Tricolor' 'Blue-Smoke'
#  'Brown-Brindle Chocolate' 'Black Black-Brindle' 'Black-Tabby Orange'
#  'Apricot Brown' 'Buff Red' 'Brown-Brindle Tan' 'Brown Red' 'Red-Tick'
#  'Blue-Tick White' 'Silver-Tabby White' 'Brown-Brindle Fawn' 'Orange Tan'
#  'Black Black-Smoke' 'Brown Chocolate' 'Liver-Tick'
#  'Black-Smoke Brown-Tabby' 'Chocolate-Point' 'Blue-Merle Tricolor'
#  'Blue Red' 'Brown-Merle Tricolor' 'Blue Tortie' 'Blue-Smoke Brown'
#  'Silver White' 'Chocolate Red' 'Brown Cream' 'Blue-Merle Cream'
#  'Orange Tortie' 'Black Brown-Merle' 'Brown Seal-Point' 'Blue-Tabby Tan'
#  'Red Red-Merle' 'Brown Tortie' 'Cream Sable' 'Black Black-Tabby'
#  'Brown-Tabby Gray' 'Tan Tan' 'Blue-Tick Brown' 'Black-Smoke Chocolate'
#  'Black-Tabby Brown' 'Brown Buff' 'Tan Yellow-Brindle' 'Blue-Tick Tan'
#  'Brown-Merle Red-Tick' 'Brown-Tabby Lynx-Point' 'Brown Torbie'
#  'Buff Liver' 'Tan Tricolor' 'Black Chocolate' 'Pink'
#  'Black Yellow-Brindle' 'Silver-Lynx-Point' 'Brown Brown-Merle'
#  'Black Orange-Tabby' 'Black Tortie' 'Brown Brown-Tabby'
#  'Blue-Cream Torbie' 'Black-Brindle Brown' 'Red Tricolor'
#  'Blue Yellow-Brindle' 'Cream Ruddy' 'Blue Cream' 'Gold Yellow'
#  'Blue-Tiger' 'Brown-Merle Tan' 'Buff Yellow' 'Gold Gold'
#  'Tortie-Point White' 'Blue-Tick Red-Tick' 'Liver Tan' 'Red-Merle Tan'
#  'Blue-Cream Buff' 'Blue Orange' 'Blue-Merle Brown-Merle' 'Pink White'
#  'Brown Calico' 'Calico Torbie' 'Blue Brown' 'Blue-Merle Red'
#  'Brown-Brindle Brown-Merle' 'Calico Orange-Tabby' 'Flame-Point White'
#  'Brown-Brindle Brown-Brindle' 'Blue-Merle Blue-Merle' 'Brown Fawn'
#  'Black Gold' 'Brown-Merle Chocolate' 'Agouti Brown-Tabby'
#  'Brown-Tabby Tortie' 'Black Yellow' 'Chocolate Red-Tick' 'Gray Red'
#  'Blue-Tick Brown-Brindle' 'Apricot Tan' 'Liver-Tick White'
#  'Cream Seal-Point' 'Gray-Tabby Lynx-Point' 'Blue-Tabby Cream'
#  'Black-Tiger White' 'Chocolate Silver' 'Silver Tricolor'
#  'Blue-Merle Red-Merle' 'Black-Smoke Tortie' 'Orange Orange-Tabby'
#  'Blue Fawn' 'Blue-Tick Red' 'Fawn Tan' 'Brown-Tabby Orange'
#  'Blue-Cream Brown-Brindle' 'Blue-Cream Calico'
#  'Black-Brindle Brown-Brindle' 'Chocolate Cream' 'Blue-Tabby Calico'
#  'Orange-Tiger' 'Cream Orange' 'Red Sable' 'Buff Gray' 'Buff Gold'
#  'Red Silver' 'Chocolate Gray' 'Brown-Tabby Gray-Tabby' 'Yellow Yellow'
#  'Black Gray-Tabby' 'Buff Sable']

# %%
OrderedBreed = data.OrderedBreed.unique()
print("Unique Breeds" , (data.OrderedBreed.value_counts() > 0).sum())
print(OrderedBreed)
# Out:
# ('Unique Breeds', 1143)
# ['Shetland-Sheepdog-Mix' 'Domestic-Shorthair-Mix' 'Pit-Bull-Mix' ...,
#  'English-Bulldog French-Bulldog' 'Boxer Vizsla'
#  'Australian-Kelpie German-Shepherd']
